# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidance to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this intire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to similate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('files/AB_NYC_2019.csv')
air_bnb
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# How many neighborhood groups are available and which shows up the most?
Nbrhood_counts = air_bnb['neighbourhood_group'].value_counts()
Nbrhood_counts
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
# Are private rooms the most popular in manhattan?
air_bnb.groupby('room_type').count()
# Out:
#                     id   name  host_id  host_name  neighbourhood_group  \
# room_type
# Entire home/apt  25409  25402    25409      25400                25409
# Private room     22326  22318    22326      22314                22326
# Shared room       1160   1159     1160       1160                 1160
#
#                  neighbourhood  latitude  longitude  price  minimum_nights  \
# room_type
# Entire home/apt          25409     25409      25409  25409           25409
# Private room             22326     22326      22326  22326           22326
# Shared room               1160      1160       1160   1160            1160
#
#                  number_of_reviews  last_review  reviews_per_month  \
# room_type
# Entire home/apt              25409        20332              20332
# Private room                 22326        17665              17665
# Shared room                   1160          846                846
#
#                  calculated_host_listings_count  availability_365  \
# ...

# %%
# Which hosts are the busiest and based on their reviews?

air_bnb.groupby('host_name').count().sort_values('reviews_per_month', ascending = False)
# Out:
#                id  name  host_id  neighbourhood_group  neighbourhood  \
# host_name
# Michael       417   417      417                  417            417
# David         403   403      403                  403            403
# John          294   294      294                  294            294
# Alex          279   279      279                  279            279
# Sonder (NYC)  327   327      327                  327            327
# ...           ...   ...      ...                  ...            ...
# Joscelyn        1     1        1                    1              1
# Dae             1     1        1                    1              1
# Navarra         1     1        1                    1              1
# Dagmara         1     1        1                    1              1
# 현선              1     1        1                    1              1
#
#               latitude  longitude  room_type  price  minimum_nights  \
# host_name
# ...

# %%
#Which neighorhood group has the highest average price?
air_bnb.groupby(['neighbourhood_group', 'price']).mean().sort_values('price', ascending = False)
# Out:
#                                      id       host_id   latitude  longitude  \
# neighbourhood_group price
# Brooklyn            10000  1.389434e+07  5.143901e+06  40.732600 -73.957390
# Queens              10000  7.003697e+06  2.058283e+07  40.768100 -73.916510
# Manhattan           10000  2.243690e+07  7.239039e+07  40.772130 -73.986650
#                     9999   1.520238e+07  3.174554e+06  40.741997 -73.969903
#                     8500   2.337741e+07  1.812846e+07  40.721970 -74.006330
# ...                                 ...           ...        ...        ...
# Brooklyn            10     2.601194e+07  1.035098e+08  40.697907 -73.949197
# Manhattan           10     1.768782e+07  7.028812e+07  40.757854 -73.976740
# Brooklyn            0      2.055804e+07  5.549736e+07  40.694308 -73.924413
# Manhattan           0      2.093385e+07  1.370929e+07  40.750910 -73.975970
# Bronx               0      2.033347e+07  1.316976e+08  40.832960 -73.886680
#
# ...

# %%
# Which neighbor hood group has the highest total price?
air_bnb.groupby(['neighbourhood_group', 'price']).count().sort_values('price', ascending = False)
# Out:
#                            id  name  host_id  host_name  neighbourhood  \
# neighbourhood_group price
# Brooklyn            10000   1     1        1          1              1
# Queens              10000   1     1        1          1              1
# Manhattan           10000   1     1        1          1              1
#                     9999    3     3        3          3              3
#                     8500    1     1        1          1              1
# ...                        ..   ...      ...        ...            ...
# Brooklyn            10      6     6        6          6              6
# Manhattan           10      7     7        7          7              7
# Brooklyn            0       9     9        9          9              9
# Manhattan           0       1     1        1          1              1
# Bronx               0       1     1        1          1              1
#
#                            latitude  longitude  room_type  minimum_nights  \
# ...

# %%
FIELDS = ['id','name','host_id','host_name','neighbourhood_group','neighbourhood','latitude','longitude','room_type',
          'price','minimum_nights','number_of_reviews','last_review','reviews_per_month','calculated_host_listings_count',
          'availability_365']

# i = integer, f = float, |s25 = string with 25 characters
DATATYPES = [('id', 'i'), ('name', '|S25'), ('host_id', 'i'), ('host_name', '|S100'), ('neighbourhood_group', '|S25'), 
             ('neighbourhood', '|S25'), ('latitude', 'i'), ('longitude', 'i'), ('room_type', '|S25'), ('price', 'i'),
             ('minimum_nights', 'i'), ('number)of_reviews', 'i'), ('last_review', '|S25'), ('reviews_per_month', 'i'),
             ('calculated_host_listings_count', 'i'), ('availability_365', 'i')]

#Which top 5 hosts have the highest total price?
def load_data(filename, d=','):
    data = np.genfromtxt(filename, delimiter = d, skip_header = 1,
                        usecols = np.arange(0,14), invalid_raise = False,
                        names = FIELDS, dtype=DATATYPES)
    return data

air_bnb = load_data('./files/AB_NYC_2019.csv')

all_host = air_bnb['host_name']

all_price = air_bnb['price']

top_price = []

for i in range(len(all_host)):
    top_price.append(all_price[i].decode('utf-8'))

zipped_values = list(zip(top_price, all_host))


sorted_hr = sorted(zipped_values, key = lambda x: x[1], reverse = True)
print(sorted_hr[0:5])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-89-7cf8bc68c392> in <module>
#      16     return data
#      17
# ---> 18 air_bnb = load_data('./files/AB_NYC_2019.csv')
#      19
#      20 all_host = air_bnb['host_name']
#
# <ipython-input-89-7cf8bc68c392> in load_data(filename, d)
#      11 #Which top 5 hosts have the highest total price?
#      12 def load_data(filename, d=','):
# ---> 13     data = np.genfromtxt(filename, delimiter = d, skip_header = 1,
#      14                         usecols = np.arange(0,14), invalid_raise = False,
#      15                         names = FIELDS, dtype=DATATYPES)
#
# ...

# %%
# Who currently has no (zero) availability with a review count of 100 or more?

air_bnb[air_bnb['number_of_reviews']>=100]
# Out:
#              id                                               name    host_id  \
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 9          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 11         5441                    Central Manhattan/near Broadway       7989
# ...         ...                                                ...        ...
# 33943  26877259       *Times Square Luxury Apartment Private Room*  172864847
# 35014  27759146             Cozy corner near Empire State Building  209549523
# 36238  28826608                                 “For Heaven Cakes”  217379941
# 37093  29489893   Beautiful furnished private studio with backyard  222098649
# 42075  32678719  Enjoy great views of the City in our Deluxe Room!  244361589
#
# ...

# %%
# What host has the highest total of prices and where are they located?

air_bnb.groupby(['host_name', 'price', 'neighbourhood_group']).sort_values('price', ascending = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-151-b4d62b822939> in <module>
#       1 # What host has the highest total of prices and where are they located?
#       2
# ----> 3 air_bnb.groupby(['host_name', 'price', 'neighbourhood_group']).sort_values('price', ascending = False)
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'sort_values'

# %%
# When did Danielle from Queens last receive a review?

air_bnb

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %%
air_bnb.groupby(['host_name', 'calculated_host_listings_count']).count().sort_values('calculated_host_listings_count', ascending = False)
# Out:
#                                               id  name  host_id  \
# host_name    calculated_host_listings_count
# Sonder (NYC) 327                             327   327      327
# Blueground   232                             232   232      232
# Kara         121                             121   121      121
# Kazuya       103                             103   103      103
# Sonder       96                               96    96       96
# ...                                          ...   ...      ...
# Isadora      1                                 2     2        2
# Isai         1                                 1     1        1
# Isai Jesse   1                                 1     1        1
# Isaiah       1                                 3     3        3
# 현선           1                                 1     1        1
#
#                                              neighbourhood_group  \
# host_name    calculated_host_listings_count
# ...

# %% [markdown]
# 2. How many listings have completely open availability?

# %%
def open_avail(row):
    open = row['availability_365']
    name = row['host_name']
    
    if open == 365:
        CompletelyOpen = True
    else:
        CompletelyOpen = False
    return CompletelyOpen

air_bnb['CompletelyOpen'] = air_bnb.apply(open_avail, axis = 1)
air_bnb.groupby('CompletelyOpen').count()[['host_name', 'availability_365']]
# Out:
#                 host_name  availability_365
# CompletelyOpen
# False               47579             47600
# True                 1295              1295

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %%
air_bnb.groupby(['room_type', 'number_of_reviews']).count().sort_values('room_type', ascending = False)
# Out:
#                                      id  name  host_id  host_name  \
# room_type       number_of_reviews
# Shared room     454                   1     1        1          1
#                 59                    4     4        4          4
#                 31                    6     6        6          6
#                 32                    7     7        7          7
#                 33                    5     5        5          5
# ...                                 ...   ...      ...        ...
# Entire home/apt 216                   5     5        5          5
#                 217                   1     1        1          1
#                 218                   2     2        2          2
#                 219                   3     3        3          3
#                 0                  5077  5075     5077       5074
#
#                                    neighbourhood_group  neighbourhood  \
# room_type       number_of_reviews
# ...

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --
